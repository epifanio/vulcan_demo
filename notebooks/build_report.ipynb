# %%
import email
import email.mime.application
import mimetypes
import smtplib
from email.mime.application import MIMEApplication
from email.mime.image import MIMEImage
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText

from jinja2 import Environment, FileSystemLoader


def sendMail(
    subject="--------------",
    msgfrom="--------------",
    msgto="---------------",
    text="testo",
    html="<b>html</b>",
    inlineimage=None,
    pdfattachment=None,
    zipattachment=None,
    msgtype="html",
    smtp="smtp.gmail.com",
    username="",
    smtp_port="587",
    password="---------------",
):
    msg = MIMEMultipart()
    msg["Subject"] = f"{subject}"
    msg["From"] = msgfrom
    # msg as plain text
    if msgtype == "plain":
        part = MIMEText(text, "plain")
        msg.attach(part)
    # msg as html
    if msgtype == "html":
        part = MIMEText(html, "html")
        msg.attach(part)

    # Inline image attachment
    if inlineimage:
        for i in inlineimage:
            if os.path.exists(i):
                ctype, encoding = mimetypes.guess_type(i)
                ctype = "application/octet-stream"
                maintype, subtype = ctype.split("/", 1)
                fp = open(i, "rb")
                part = MIMEImage(fp.read(), _subtype=subtype)
                part.add_header("Content-Disposition", "attachment", filename=i)
                fp.close()
                msg.attach(part)
    # zip
    if zipattachment:
        with open(zipattachment, "rb") as file:
            # Attach the file with filename to the email
            msg.attach(MIMEApplication(file.read(), Name="report.zip"))

    # PDF attachment
    if pdfattachment:
        for i in pdfattachment:
            if os.path.exists(i):
                fp = open(i, "rb")
                att = email.mime.application.MIMEApplication(fp.read(), _subtype="pdf")
                fp.close()
                att.add_header("Content-Disposition", "attachment", filename=i)
                msg.attach(att)

    s = smtplib.SMTP(smtp, smtp_port)
    s.starttls()  # enable security
    s.login(msgfrom, password)  # login with mail_id and password
    # s.login(username, password)
    s.sendmail(msgfrom, msgto, msg.as_string())
    s.quit()

# %%
report = {
    "simulation_run": "eemep_hourInst_20210409T024601",
    "nc_url": "https://thredds.met.no/thredds/dodsC/metusers/heikok/ash/krisuvik/eemep_hourInst_20210409T024601.nc",
    "warnings": [
        {
            "min": "211181.27",
            "max": "240934.38",
            "mean": "223763.56",
            "cells": "3",
            "datetime": "2021-04-10T11:00:00",
            "geojson": "output/eemep_hourInst_20210409T024601/feature/2021-04-10T11:00:00.geojson",
            "location": [5.067, 60.333],
            "image": "output/eemep_hourInst_20210409T024601/images/2021-04-10T11:00:00.png",
        },
        {
            "min": "203003.77",
            "max": "413188.44",
            "mean": "280289.34",
            "cells": "34",
            "datetime": "2021-04-10T12:00:00",
            "geojson": "output/eemep_hourInst_20210409T024601/feature/2021-04-10T12:00:00.geojson",
            "location": [5.709, 60.288],
            "image": "output/eemep_hourInst_20210409T024601/images/2021-04-10T12:00:00.png",
        },
        {
            "min": "200857.44",
            "max": "490496.47",
            "mean": "320277.12",
            "cells": "90",
            "datetime": "2021-04-10T13:00:00",
            "geojson": "output/eemep_hourInst_20210409T024601/feature/2021-04-10T13:00:00.geojson",
            "location": [6.359, 60.199],
            "image": "output/eemep_hourInst_20210409T024601/images/2021-04-10T13:00:00.png",
        },
        {
            "min": "200640.8",
            "max": "515275.03",
            "mean": "349788.25",
            "cells": "139",
            "datetime": "2021-04-10T14:00:00",
            "geojson": "output/eemep_hourInst_20210409T024601/feature/2021-04-10T14:00:00.geojson",
            "location": [6.863, 60.182],
            "image": "output/eemep_hourInst_20210409T024601/images/2021-04-10T14:00:00.png",
        },
        {
            "min": "201065.34",
            "max": "509017.16",
            "mean": "337046.88",
            "cells": "179",
            "datetime": "2021-04-10T15:00:00",
            "geojson": "output/eemep_hourInst_20210409T024601/feature/2021-04-10T15:00:00.geojson",
            "location": [7.44, 60.125],
            "image": "output/eemep_hourInst_20210409T024601/images/2021-04-10T15:00:00.png",
        },
        {
            "min": "200115.11",
            "max": "424371.47",
            "mean": "288432.75",
            "cells": "239",
            "datetime": "2021-04-10T16:00:00",
            "geojson": "output/eemep_hourInst_20210409T024601/feature/2021-04-10T16:00:00.geojson",
            "location": [7.982, 60.112],
            "image": "output/eemep_hourInst_20210409T024601/images/2021-04-10T16:00:00.png",
        },
        {
            "min": "200164.95",
            "max": "324391.78",
            "mean": "259044.47",
            "cells": "261",
            "datetime": "2021-04-10T17:00:00",
            "geojson": "output/eemep_hourInst_20210409T024601/feature/2021-04-10T17:00:00.geojson",
            "location": [8.622, 60.073],
            "image": "output/eemep_hourInst_20210409T024601/images/2021-04-10T17:00:00.png",
        },
        {
            "min": "200192.77",
            "max": "321403.16",
            "mean": "231636.86",
            "cells": "233",
            "datetime": "2021-04-10T18:00:00",
            "geojson": "output/eemep_hourInst_20210409T024601/feature/2021-04-10T18:00:00.geojson",
            "location": [8.892, 60.039],
            "image": "output/eemep_hourInst_20210409T024601/images/2021-04-10T18:00:00.png",
        },
        {
            "min": "200054.4",
            "max": "276276.88",
            "mean": "224229.1",
            "cells": "92",
            "datetime": "2021-04-10T19:00:00",
            "geojson": "output/eemep_hourInst_20210409T024601/feature/2021-04-10T19:00:00.geojson",
            "location": [8.817, 60.0],
            "image": "output/eemep_hourInst_20210409T024601/images/2021-04-10T19:00:00.png",
        },
        {
            "min": "200251.86",
            "max": "254603.5",
            "mean": "213254.72",
            "cells": "42",
            "datetime": "2021-04-10T20:00:00",
            "geojson": "output/eemep_hourInst_20210409T024601/feature/2021-04-10T20:00:00.geojson",
            "location": [6.762, 59.872],
            "image": "output/eemep_hourInst_20210409T024601/images/2021-04-10T20:00:00.png",
        },
        {
            "min": "200493.92",
            "max": "233730.34",
            "mean": "211885.84",
            "cells": "5",
            "datetime": "2021-04-10T21:00:00",
            "geojson": "output/eemep_hourInst_20210409T024601/feature/2021-04-10T21:00:00.geojson",
            "location": [6.433, 59.767],
            "image": "output/eemep_hourInst_20210409T024601/images/2021-04-10T21:00:00.png",
        },
        {
            "min": "201392.77",
            "max": "215769.58",
            "mean": "208581.17",
            "cells": "2",
            "datetime": "2021-04-10T22:00:00",
            "geojson": "output/eemep_hourInst_20210409T024601/feature/2021-04-10T22:00:00.geojson",
            "location": [5.3, 59.5],
            "image": "output/eemep_hourInst_20210409T024601/images/2021-04-10T22:00:00.png",
        },
    ],
    "geojson": [
        "output/eemep_hourInst_20210409T024601/feature/2021-04-10T11:00:00.geojson",
        "output/eemep_hourInst_20210409T024601/feature/2021-04-10T12:00:00.geojson",
        "output/eemep_hourInst_20210409T024601/feature/2021-04-10T13:00:00.geojson",
        "output/eemep_hourInst_20210409T024601/feature/2021-04-10T14:00:00.geojson",
        "output/eemep_hourInst_20210409T024601/feature/2021-04-10T15:00:00.geojson",
        "output/eemep_hourInst_20210409T024601/feature/2021-04-10T16:00:00.geojson",
        "output/eemep_hourInst_20210409T024601/feature/2021-04-10T17:00:00.geojson",
        "output/eemep_hourInst_20210409T024601/feature/2021-04-10T18:00:00.geojson",
        "output/eemep_hourInst_20210409T024601/feature/2021-04-10T19:00:00.geojson",
        "output/eemep_hourInst_20210409T024601/feature/2021-04-10T20:00:00.geojson",
        "output/eemep_hourInst_20210409T024601/feature/2021-04-10T21:00:00.geojson",
        "output/eemep_hourInst_20210409T024601/feature/2021-04-10T22:00:00.geojson",
        "output/eemep_hourInst_20210409T024601/feature/eemep_hourInst_20210409T024601.geojson",
    ],
    "image": [
        "output/eemep_hourInst_20210409T024601/images/eemep_hourInst_20210409T024601_0_12.png",
        "output/eemep_hourInst_20210409T024601/images/eemep_hourInst_20210409T024601_12_24.png",
        "output/eemep_hourInst_20210409T024601/images/eemep_hourInst_20210409T024601_24_36.png",
        "output/eemep_hourInst_20210409T024601/images/eemep_hourInst_20210409T024601_36_48.png",
    ],
}

# %%
import jinja2
from IPython.core.display import HTML

jinja_environment = jinja2.Environment(loader=jinja2.FileSystemLoader("templates/"))
template = jinja_environment.get_template("download/download.html")

html = template.render(
    {
        "simulation_run": report["simulation_run"],
        "data": report["warnings"],
        "nc_url": report["nc_url"],
        "image_sequence": report["image"],
    }
)

HTML(html)

# %%
with open("report.html", "w") as f:
    f.write(html)

# %%
import zipfile

# %%
zip_file = zipfile.ZipFile("report.zip", "a")

# %%
zip_file.write("report.html", "eemep_hourInst_20210409T024601_report/report.html")

# %%
from pathlib import Path

root_directory = Path("output/eemep_hourInst_20210409T024601")
for path_object in root_directory.glob("**/*"):
    if path_object.is_file():
        zip_file.write(
            path_object, Path("eemep_hourInst_20210409T024601_report" / path_object)
        )

# %%
zip_file.close()

# %%
jinja_environment = jinja2.Environment(loader=jinja2.FileSystemLoader("templates/"))
template = jinja_environment.get_template("download/mail_report.html")

html = template.render(
    {
        "simulation_run": report["simulation_run"],
        "data": report["warnings"],
        "nc_url": report["nc_url"],
        "image_sequence": report["image"],
    }
)

HTML(html)

# %%
sendMail()

# %%
sendMail(
    subject="---------------",
    msgfrom="----------------",
    msgto="-------------------",
    html=html,
    zipattachment="report.zip",
    msgtype="html",
    smtp="smtp.gmail.com",
    username="",
    smtp_port="587",
    password="---------------",
)

# %%
import json

import requests


def get_gist(token, content, output):
    GITHUB_API = "https://api.github.com"
    API_TOKEN = "------------------------------"
    url = GITHUB_API + "/gists"
    headers = {"Authorization": "token %s" % API_TOKEN}

    params = {"scope": "gist"}
    payload = {
        "description": "Test GIST created by python code",
        "public": True,
        "files": {
            output: {
                "content": content
            }
        },
    }
    res=requests.post(url,headers=headers,params=params,data=json.dumps(payload))
    j=json.loads(res.text)
    return j['html_url']

# %%
with open('2021-04-08T06:00:00.geojson', 'r') as f:
    content = f.read()
    gist = get_gist(token="", content=content, output="test.geojson")

# %%
gist
